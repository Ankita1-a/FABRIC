# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# FACMIC with BiomedCLIP — Federated Adaptive CLIP Model for Medical Image Classification
# ========================================================================================
# Training clients  : client_0, client_1, client_2 \
# Target domain     : client_3  (used UNLABELLED for LMMD domain adaptation) \
# Test set          : client_3  (evaluated with labels after training)
#
# Design follows the FACMIC paper (Wu et al., MICCAI):\
#   • Frozen BiomedCLIP encoders \
#   • Lightweight 5-layer feature-attention module per client\
#   • Contrastive loss   Lcontr  \
#   • LMMD domain-adaptation loss  LDA  — source = each training\
#     client, target = client_3 images (no labels used)\
#   • FedAVG weighted aggregation of attention parameters only  \
#   • Dynamic per-image text prompts from llm_prompts_1.json;\
#     class-level fallback when an image has no JSON entry
#
# Requirements
# ------------
# pip install open_clip_torch torch torchvision scikit-learn Pillow tqdm

# %%
# !pip install open_clip_torch torch torchvision scikit-learn Pillow tqdm
# Out:
# Requirement already satisfied: open_clip_torch in /usr/local/lib/python3.12/dist-packages (3.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cu128)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (2025.11.3)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (6.3.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (1.8.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.7.0)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (1.0.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.17->open_clip_torch) (6.0.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open_clip_torch) (0.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (26.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (0.24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->open_clip_torch) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->open_clip_torch) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub->open_clip_torch) (0.1.2)

# %%
import argparse
import copy
import json
import os
import random
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm

import open_clip

# %%
# ────────────────────────────────────────────────────────────────────────────
# Constants & reproducibility
# ────────────────────────────────────────────────────────────────────────────
CLASS_NAMES = ["glioma_tumor", "meningioma_tumor", "no_tumor", "pituitary_tumor"]
CLASS2IDX   = {c: i for i, c in enumerate(CLASS_NAMES)}

# Fallback prompts when an image path is absent from llm_prompts_1.json
FALLBACK_PROMPTS = {
    "glioma_tumor":     "brain MRI showing glioma tumor",
    "meningioma_tumor": "brain MRI showing meningioma tumor",
    "no_tumor":         "brain MRI showing no tumor",
    "pituitary_tumor":  "brain MRI showing pituitary tumor",
}


def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
DATA_ROOT    = "/content/drive/MyDrive/FACMIC/data/BrainTumor"
PROMPTS_JSON = "/content/drive/MyDrive/FACMIC/llm_prompts_1.json"
OUTPUT_DIR   = "/content/drive/MyDrive/FACMIC/outputs_async"

# ── Hyperparameters ──────────────────────────────────────────────────────────
ROUNDS       = 50
EPOCHS       = 1       # local epochs per round
BATCH_SIZE   = 32
LR           = 0.001
LMMD_LAMBDA  = 1.0
TEMPERATURE  = 0.07
EVAL_EVERY   = 2
SEED         = 42
# ────────────────────────────────────────────────────────────────────────────

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
print("Loading BiomedCLIP ...")
biomedclip, _, preprocess = open_clip.create_model_and_transforms(
    "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
)
tokenizer = open_clip.get_tokenizer(
    "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
)
biomedclip = biomedclip.to(device).eval()
for p in biomedclip.parameters():
    p.requires_grad_(False)

# Infer feature dimension
with torch.no_grad():
    FEAT_DIM = biomedclip.encode_image(
        torch.zeros(1, 3, 224, 224, device=device)
    ).shape[-1]

print(f"BiomedCLIP loaded. Feature dim = {FEAT_DIM}")
# Out:
# Loading BiomedCLIP ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# BiomedCLIP loaded. Feature dim = 512

# %%
# ────────────────────────────────────────────────────────────────────────────
# BiomedCLIP loader
# ────────────────────────────────────────────────────────────────────────────
def load_biomedclip(device: torch.device):
    """
    Load Microsoft BiomedCLIP-PubMedBERT-256-vit_L_14 via open_clip.
    Returns (model, tokenizer, preprocess_val).
    All BiomedCLIP parameters are frozen — only the attention module trains.
    """
    model, _, preprocess_val = open_clip.create_model_and_transforms(
        "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
    )
    tokenizer = open_clip.get_tokenizer(
        "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
    )
    model = model.to(device).eval()
    for p in model.parameters():
        p.requires_grad_(False)
    return model, tokenizer, preprocess_val

# %%
# ────────────────────────────────────────────────────────────────────────────
# Datasets
# ────────────────────────────────────────────────────────────────────────────
class BrainTumorDataset(Dataset):
    """
    Labelled dataset for a single client directory.

    Directory layout:
        <client_dir>/
            glioma_tumor/     *.jpg
            meningioma_tumor/ *.jpg
            no_tumor/         *.jpg
            pituitary_tumor/  *.jpg

    Parameters
    ----------
    client_dir : str   — path to the client folder
    prompts    : dict  — {json_path_key: prompt_string}
    transform          — open_clip / torchvision preprocessing
    split      : str   — 'train' | 'val' | 'test'  (80 / 10 / 10 per class)
    seed       : int
    """

    def __init__(
        self,
        client_dir: str,
        prompts: Dict[str, str],
        transform,
        split: str = "train",
        seed: int = 42,
    ):
        self.transform = transform
        self.prompts   = prompts
        # (abs_path, label_int, prompt_string)
        self.samples: List[Tuple[str, int, str]] = []

        for cls_name in CLASS_NAMES:
            cls_dir = Path(client_dir) / cls_name
            if not cls_dir.exists():
                continue
            files = sorted(
                p for p in cls_dir.iterdir()
                if p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp"}
            )
            rng = random.Random(seed)
            rng.shuffle(files)
            n       = len(files)
            n_train = int(0.8 * n)
            n_val   = int(0.1 * n)
            if (split=='train') or (split=='val'):
                splits  = {
                    "train": files[:n_train],
                    "val":   files[n_train : n_train + n_val],
                    "test":  files[n_train + n_val :],
                }
            else:
                splits  = {
                    "test":  files
                }
            for fpath in splits[split]:
                prompt = self._resolve_prompt(fpath, cls_name)
                self.samples.append((str(fpath), CLASS2IDX[cls_name], prompt))

    def _resolve_prompt(self, fpath: Path, cls_name: str) -> str:
        """Match by filename; fall back to class-level prompt."""
        stem = fpath.name
        for key, val in self.prompts.items():
            if key.endswith(stem):
                return val
        return FALLBACK_PROMPTS[cls_name]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label, prompt = self.samples[idx]
        img = Image.open(path).convert("RGB")
        return self.transform(img), label, prompt


class UnlabelledDataset(Dataset):
    """
    Loads images from a directory WITHOUT labels.
    Used for client_3 as the LMMD target domain during training.
    Only the train split (50 %:50%) is used so the test images stay unseen.
    """

    def __init__(self, client_dir: str, transform, seed: int = 42):
        self.transform = transform
        self.paths: List[str] = []

        for cls_name in CLASS_NAMES:
            cls_dir = Path(client_dir) / cls_name
            if not cls_dir.exists():
                continue
            files = sorted(
                p for p in cls_dir.iterdir()
                if p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp"}
            )
            rng = random.Random(seed)
            rng.shuffle(files)
            n_train = len(files)
            # Only train-split images — test images must stay completely unseen
            self.paths.extend(str(f) for f in files[:n_train])

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert("RGB")
        return self.transform(img)   # no label, no prompt

# %%
with open(PROMPTS_JSON) as f:
    prompts_dict = json.load(f)
print(f"Loaded {len(prompts_dict)} prompts.")

root              = Path(DATA_ROOT)
train_client_dirs = [str(root / f"client_{i}") for i in range(3)]
target_dir        = str(root / "client_3")

train_loaders, val_loaders = [], []
for cd in train_client_dirs:
    ds_tr = BrainTumorDataset(cd, prompts_dict, preprocess, "train", SEED)
    ds_va = BrainTumorDataset(cd, prompts_dict, preprocess, "val",   SEED)
    train_loaders.append(DataLoader(ds_tr, batch_size=BATCH_SIZE,
                                    shuffle=True,  num_workers=2,
                                    pin_memory=True, drop_last=True))
    val_loaders.append( DataLoader(ds_va, batch_size=BATCH_SIZE,
                                    shuffle=False, num_workers=2,
                                    pin_memory=True))

target_loader = DataLoader(
    UnlabelledDataset(target_dir, preprocess, SEED),
    batch_size=BATCH_SIZE, shuffle=True,
    num_workers=2, pin_memory=True, drop_last=True,
)
test_loader = DataLoader(
    BrainTumorDataset(target_dir, prompts_dict, preprocess, "test", SEED),
    batch_size=BATCH_SIZE, shuffle=False,
    num_workers=2, pin_memory=True,
)

train_sizes = [len(dl.dataset) for dl in train_loaders]
print(f"Train sizes         : {train_sizes}")
print(f"Target (C3) unlabelled : {len(target_loader.dataset)}")
print(f"Test   (C3) labelled   : {len(test_loader.dataset)}")
# Out:
# Loaded 3244 prompts.
# Train sizes         : [1180, 338, 758]
# Target (C3) unlabelled : 394
# Test   (C3) labelled   : 394

# %%
# ────────────────────────────────────────────────────────────────────────────
# Feature-Attention Module
# ────────────────────────────────────────────────────────────────────────────
class FeatureAttentionModule(nn.Module):
    """
    ai(·) : R^D -> [0,1]^D
    Linear -> BN -> LeakyReLU -> Linear -> Softmax
    Only this module is trained and communicated between clients and server.
    """

    def __init__(self, feat_dim: int):
        super().__init__()
        hidden = max(feat_dim // 4, 64)
        self.net = nn.Sequential(
            nn.Linear(feat_dim, hidden),
            nn.BatchNorm1d(hidden),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Linear(hidden, feat_dim),
            nn.Softmax(dim=-1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """x: (B, D) -> masked features (B, D)"""
        return self.net(x) * x   # Hadamard product

# %%
# ────────────────────────────────────────────────────────────────────────────
# Contrastive loss
# ────────────────────────────────────────────────────────────────────────────
def contrastive_loss(
    img_feats: torch.Tensor,   # (B, D)
    txt_feats: torch.Tensor,   # (B, D)
    temperature: float = 0.07,
) -> torch.Tensor:
    """
    Symmetric cross-entropy over the B x B cosine-similarity matrix.
    Lcontr = -1/B sum_j 1/2 [log p_jj + log q_jj]
    """
    img_n  = F.normalize(img_feats, dim=-1)
    txt_n  = F.normalize(txt_feats, dim=-1)
    S      = img_n @ txt_n.T / temperature
    labels = torch.arange(S.size(0), device=S.device)
    return (F.cross_entropy(S, labels) + F.cross_entropy(S.T, labels)) / 2.0

# %%
# ────────────────────────────────────────────────────────────────────────────
# LMMD loss
# ────────────────────────────────────────────────────────────────────────────
def gaussian_kernel(
    x: torch.Tensor,
    y: torch.Tensor,
    bandwidth: Optional[float] = None,
) -> torch.Tensor:
    diff = x.unsqueeze(1) - y.unsqueeze(0)   # (n, m, D)
    sq   = (diff ** 2).sum(-1)               # (n, m)
    if bandwidth is None:
        bandwidth = sq.detach().median().clamp(min=1e-6).item()
    return torch.exp(-sq / (2.0 * bandwidth))

def lmmd_loss(
    src_feats:   torch.Tensor,   # (ns, D)  masked source (training client)
    tgt_feats:   torch.Tensor,   # (nt, D)  masked target (client_3, no labels)
    src_labels:  torch.Tensor,   # (ns,)    integer class labels
    tgt_probs:   torch.Tensor,   # (nt, K)  pseudo-label probabilities
    num_classes: int,
    bandwidth:   Optional[float] = None,
) -> torch.Tensor:
    """
    Local Maximum Mean Discrepancy.
    Source Ds = current training client (labelled).
    Target Dt = client_3 images (unlabelled, pseudo-labelled via Eq. 3).
    """
    K_ss = gaussian_kernel(src_feats, src_feats, bandwidth)
    K_tt = gaussian_kernel(tgt_feats, tgt_feats, bandwidth)
    K_st = gaussian_kernel(src_feats, tgt_feats, bandwidth)

    loss = torch.tensor(0.0, device=src_feats.device)

    for c in range(num_classes):
        # Source: hard label weights
        src_mask = (src_labels == c).float()
        ws = src_mask / src_mask.sum().clamp(min=1e-6)

        # Target: soft pseudo-label weights
        wt = tgt_probs[:, c]
        wt = wt / wt.sum().clamp(min=1e-6)

        term_ss = (ws.unsqueeze(1) * ws.unsqueeze(0) * K_ss).sum()
        term_tt = (wt.unsqueeze(1) * wt.unsqueeze(0) * K_tt).sum()
        term_st = (ws.unsqueeze(1) * wt.unsqueeze(0) * K_st).sum()

        loss += term_ss + term_tt - 2.0 * term_st

    return loss / num_classes

# %%
# ────────────────────────────────────────────────────────────────────────────
# Helpers: encoding & prediction
# ────────────────────────────────────────────────────────────────────────────
@torch.no_grad()
def encode_class_prompts():
    tokens = tokenizer([FALLBACK_PROMPTS[c] for c in CLASS_NAMES]).to(device)
    return F.normalize(biomedclip.encode_text(tokens), dim=-1)

@torch.no_grad()
def encode_batch_prompts(prompts):
    tokens = tokenizer(prompts).to(device)
    return F.normalize(biomedclip.encode_text(tokens), dim=-1)

@torch.no_grad()
def predict_probs(masked_img_feats, class_txt_feats, temperature=0.07):
    img_n = F.normalize(masked_img_feats, dim=-1)
    txt_n = F.normalize(class_txt_feats,  dim=-1)
    return F.softmax(img_n @ txt_n.T / temperature, dim=-1)
# Pre-compute class text features once
class_txt_feats = encode_class_prompts()
print(f"Class text features shape: {class_txt_feats.shape}")
# Out:
# Class text features shape: torch.Size([4, 512])

# %%
# ────────────────────────────────────────────────────────────────────────────
# One local training epoch
# ────────────────────────────────────────────────────────────────────────────
def local_train_epoch(attention_module, optimizer,
                      train_loader, tgt_iter_state):
    attention_module.train()
    total_loss, steps = 0.0, 0
    tgt_iter = tgt_iter_state["iter"]

    for imgs, labels, prompts in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)

        with torch.no_grad():
            src_raw = biomedclip.encode_image(imgs) # Passing image through image encoder

        txt_feats  = encode_batch_prompts(list(prompts)) # Passing prompts through text encoder
        masked_src = attention_module(src_raw)
        l_contr    = contrastive_loss(masked_src, txt_feats, TEMPERATURE)

        try:
            tgt_imgs = next(tgt_iter)
        except StopIteration:
            tgt_iter = iter(target_loader)
            tgt_iter_state["iter"] = tgt_iter
            tgt_imgs = next(tgt_iter)

        tgt_imgs = tgt_imgs.to(device)
        with torch.no_grad():
            tgt_raw    = biomedclip.encode_image(tgt_imgs)
            masked_tgt = attention_module(tgt_raw)
            tgt_probs  = predict_probs(masked_tgt, class_txt_feats, TEMPERATURE)

        l_da = lmmd_loss(masked_src.detach(), masked_tgt.detach(),
                         labels, tgt_probs, len(CLASS_NAMES))
        if imgs.size(0) < 16:
            l_da = l_da * 0.1

        loss = l_contr + LMMD_LAMBDA * l_da
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        steps      += 1

    return total_loss / max(steps, 1)

# %%
# ────────────────────────────────────────────────────────────────────────────
# Evaluation
# ────────────────────────────────────────────────────────────────────────────
@torch.no_grad()
def evaluate(attention_module, loader):
    attention_module.eval()
    all_preds, all_labels = [], []
    for imgs, labels, _ in loader:
        imgs   = imgs.to(device)
        masked = attention_module(biomedclip.encode_image(imgs))
        preds  = predict_probs(masked, class_txt_feats, TEMPERATURE).argmax(-1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
    acc  = accuracy_score(all_labels, all_preds) * 100.0
    bacc = balanced_accuracy_score(all_labels, all_preds) * 100.0
    return acc, bacc

@torch.no_grad()
def evaluate_train(attention_module, loader):
    """
    Evaluate on a training loader.
    Training loader has drop_last=True and shuffle=True — we just run one
    full pass over whatever batches are available.  No gradient, eval mode.
    """
    attention_module.eval()
    all_preds, all_labels = [], []
    for imgs, labels, _ in loader:
        imgs   = imgs.to(device)
        masked = attention_module(biomedclip.encode_image(imgs))
        preds  = predict_probs(masked, class_txt_feats, TEMPERATURE).argmax(-1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
    acc  = accuracy_score(all_labels, all_preds) * 100.0
    bacc = balanced_accuracy_score(all_labels, all_preds) * 100.0
    return acc, bacc

# %%
# ────────────────────────────────────────────────────────────────────────────
# FedAVG aggregation
# ────────────────────────────────────────────────────────────────────────────
def fedavg_aggregate(
    client_state_dicts: List[dict],
    client_sizes:       List[int],
) -> dict:

    total   = sum(client_sizes)
    weights = [s / total for s in client_sizes]
    agg     = copy.deepcopy(client_state_dicts[0])
    for key in agg:
        agg[key] = sum(
            w * sd[key].float()
            for w, sd in zip(weights, client_state_dicts)
        )
    return agg

# %%
set_seed(1)

global_attention = FeatureAttentionModule(FEAT_DIM).to(device)
best_acc     = 0.0

# ── Per-round history (one entry per round) ──────────────────────────────────
history = {
    # averaged across the ACTIVE clients each round (not all 3)
    "train_acc":       [], "train_bacc":  [],
    "val_acc":         [], "val_bacc":    [],
    # client_3 test set
    "test_acc":        [], "test_bacc":   [],
    "rounds":          [],
    # which 2 clients were selected each round
    "active_clients":  [],
}

# ── Per-client participation tracker ─────────────────────────────────────────
# rounds_trained[cid] = number of rounds this client was selected
rounds_trained = {0: 0, 1: 0, 2: 0}

# Use a separate RNG for client selection so it is independent of data shuffling
selection_rng = random.Random(42)

print("=" * 65)
print("  FACMIC-BiomedCLIP | Train: C0,C1,C2 (2 active/round) | Target+Test: C3")
print("=" * 65)

for round_idx in range(1, ROUNDS + 1):
    print('-' * 65)
    print(f"TRAINING FOR ROUND : {round_idx}")

    # ── Randomly select 2 out of 3 clients for this round ────────────────────
    active_clients = sorted(selection_rng.sample([0, 1, 2], k=2))
    skipped_client = [c for c in range(3) if c not in active_clients][0]
    print(f"  Active clients : {active_clients}  |  Skipped: client_{skipped_client}")

    # Update participation counter
    for cid in active_clients:
        rounds_trained[cid] += EPOCHS

    client_states          = []
    active_train_sizes     = []   # sizes of only the active clients (for weighted avg)
    round_train_accs,  round_train_baccs  = [], []
    round_val_accs,    round_val_baccs    = [], []

    # ── Local training — only active clients ──────────────────────────────────
    for cid in active_clients:
        print(f"  TRAINING CLIENT : {cid}")
        local_attn = FeatureAttentionModule(FEAT_DIM).to(device)
        local_attn.load_state_dict(copy.deepcopy(global_attention.state_dict()))

        optimizer = torch.optim.Adam(
            local_attn.parameters(), lr=LR,
            betas=(0.9, 0.98), weight_decay=0.02,
        )
        tgt_iter_state = {"iter": iter(target_loader)}

        for _ in range(EPOCHS):
            local_train_epoch(local_attn, optimizer,
                              train_loaders[cid], tgt_iter_state)

        # Evaluate local model before aggregation
        tr_acc,  tr_bacc  = evaluate_train(local_attn, train_loaders[cid])
        val_acc, val_bacc = evaluate(local_attn, val_loaders[cid])

        round_train_accs.append(tr_acc);   round_train_baccs.append(tr_bacc)
        round_val_accs.append(val_acc);    round_val_baccs.append(val_bacc)

        client_states.append(copy.deepcopy(local_attn.state_dict()))
        active_train_sizes.append(train_sizes[cid])   # weight by this client's data size

    # ── FedAVG aggregation — only over active clients (Eq. 8) ─────────────────
    global_attention.load_state_dict(
        fedavg_aggregate(client_states, active_train_sizes)
    )

    # ── Weight norm tracking ───────────────────────────────────────────────────
    param_norms = {}
    for name, param in global_attention.named_parameters():
        param_norms[name] = param.data.norm().item()
    print(f"\n  Round {round_idx} | Global Attention Weight Norms:")
    for name, norm in param_norms.items():
        print(f"    {name:40s} | norm = {norm:.6f}")

    # ── Test evaluation — current global model on client_3 ────────────────────
    test_acc, test_bacc = evaluate(global_attention, test_loader)

    # ── Average metrics across active clients and store ───────────────────────
    mean_val_acc  = float(np.mean(round_val_accs))
    mean_val_bacc = float(np.mean(round_val_baccs))

    history["rounds"].append(round_idx)
    history["train_acc"].append(float(np.mean(round_train_accs)))
    history["train_bacc"].append(float(np.mean(round_train_baccs)))
    history["val_acc"].append(mean_val_acc)
    history["val_bacc"].append(mean_val_bacc)
    history["test_acc"].append(float(test_acc))
    history["test_bacc"].append(float(test_bacc))
    history["active_clients"].append(active_clients)

    # ── Save best model by validation accuracy ────────────────────────────────
    if test_acc > best_acc:
        best_acc = test_acc
        print(f"  [*] Best model saved (ACC={best_acc:.2f}%)")
        torch.save(global_attention.state_dict(),
                   f"{OUTPUT_DIR}/best_attention.pt")

    # ── Print every EVAL_EVERY rounds ─────────────────────────────────────────
    if round_idx % EVAL_EVERY == 0 or round_idx == ROUNDS:
        print(
            f"\n  Round {round_idx:04d}/{ROUNDS} | "
            f"Active={active_clients} | "
            f"Train ACC={history['train_acc'][-1]:.2f}%  "
            f"Val ACC={mean_val_acc:.2f}%  "
            f"Test ACC={test_acc:.2f}%  "
            f"Test BACC={test_bacc:.2f}%"
        )

# ── Print participation summary ───────────────────────────────────────────────
print("\n" + "=" * 65)
print("  Client Participation Summary")
print("=" * 65)
for cid in range(3):
    print(f"  client_{cid} : trained for {rounds_trained[cid]} epoch(s) "
          f"across {rounds_trained[cid] // EPOCHS} round(s)")

# Save full history
with open(f"{OUTPUT_DIR}/history.json", "w") as f:
    json.dump(history, f, indent=2)

# Save results_log (lightweight — test only)
results_log = [
    {"round": r, "acc": a, "bacc": b, "active_clients": ac}
    for r, a, b, ac in zip(
        history["rounds"], history["test_acc"],
        history["test_bacc"], history["active_clients"]
    )
]
with open(f"{OUTPUT_DIR}/training_log.json", "w") as f:
    json.dump(results_log, f, indent=2)

# Save participation log
participation_log = {
    f"client_{cid}": {
        "rounds_selected": rounds_trained[cid] // EPOCHS,
        "epochs_trained":  rounds_trained[cid],
        "selection_rate":  f"{100 * (rounds_trained[cid] // EPOCHS) / ROUNDS:.1f}%",
    }
    for cid in range(3)
}
with open(f"{OUTPUT_DIR}/participation_log.json", "w") as f:
    json.dump(participation_log, f, indent=2)

print(f"Best test ACC (checkpoint): {best_acc:.2f}%")
print(f"Saved: history.json | training_log.json | participation_log.json")
# Out:
# =================================================================
#   FACMIC-BiomedCLIP | Train: C0,C1,C2 (2 active/round) | Target+Test: C3
# =================================================================
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 1
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 1 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 5.158122
#     net.0.bias                               | norm = 0.065390
#     net.1.weight                             | norm = 10.967925
#     net.1.bias                               | norm = 0.135802
#     net.3.weight                             | norm = 8.579534
#     net.3.bias                               | norm = 0.805985
#   [*] Best model saved (ACC=78.68%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 2
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 2 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 3.890641
#     net.0.bias                               | norm = 0.004416
#     net.1.weight                             | norm = 10.628710
#     net.1.bias                               | norm = 0.224709
#     net.3.weight                             | norm = 5.406553
#     net.3.bias                               | norm = 0.528709
#
#   Round 0002/50 | Active=[0, 1] | Train ACC=89.09%  Val ACC=84.08%  Test ACC=76.65%  Test BACC=76.50%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 3
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 3 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 3.137516
#     net.0.bias                               | norm = 0.000780
#     net.1.weight                             | norm = 10.282269
#     net.1.bias                               | norm = 0.304620
#     net.3.weight                             | norm = 3.827268
#     net.3.bias                               | norm = 0.377409
#   [*] Best model saved (ACC=79.95%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 4
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 4 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 2.725690
#     net.0.bias                               | norm = 0.000722
#     net.1.weight                             | norm = 9.935546
#     net.1.bias                               | norm = 0.364038
#     net.3.weight                             | norm = 3.328782
#     net.3.bias                               | norm = 0.322041
#
#   Round 0004/50 | Active=[0, 2] | Train ACC=89.68%  Val ACC=86.05%  Test ACC=79.95%  Test BACC=79.77%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 5
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 5 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 2.427828
#     net.0.bias                               | norm = 0.000698
#     net.1.weight                             | norm = 9.589573
#     net.1.bias                               | norm = 0.407217
#     net.3.weight                             | norm = 3.179353
#     net.3.bias                               | norm = 0.307996
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 6
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 6 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 2.292904
#     net.0.bias                               | norm = 0.001947
#     net.1.weight                             | norm = 9.375691
#     net.1.bias                               | norm = 0.434147
#     net.3.weight                             | norm = 3.107345
#     net.3.bias                               | norm = 0.306939
#   [*] Best model saved (ACC=80.71%)
#
#   Round 0006/50 | Active=[1, 2] | Train ACC=90.74%  Val ACC=87.36%  Test ACC=80.71%  Test BACC=80.65%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 7
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 7 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 2.165672
#     net.0.bias                               | norm = 0.000890
#     net.1.weight                             | norm = 9.029461
#     net.1.bias                               | norm = 0.469214
#     net.3.weight                             | norm = 3.045258
#     net.3.bias                               | norm = 0.311837
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 8
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 8 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 2.057599
#     net.0.bias                               | norm = 0.000832
#     net.1.weight                             | norm = 8.684303
#     net.1.bias                               | norm = 0.504876
#     net.3.weight                             | norm = 3.073766
#     net.3.bias                               | norm = 0.317980
#   [*] Best model saved (ACC=81.22%)
#
#   Round 0008/50 | Active=[0, 2] | Train ACC=90.00%  Val ACC=85.06%  Test ACC=81.22%  Test BACC=81.34%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 9
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 9 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 2.022120
#     net.0.bias                               | norm = 0.000798
#     net.1.weight                             | norm = 8.338542
#     net.1.bias                               | norm = 0.518131
#     net.3.weight                             | norm = 3.018449
#     net.3.bias                               | norm = 0.321705
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 10
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 10 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.958944
#     net.0.bias                               | norm = 0.000774
#     net.1.weight                             | norm = 7.992532
#     net.1.bias                               | norm = 0.558016
#     net.3.weight                             | norm = 3.075372
#     net.3.bias                               | norm = 0.337331
#
#   Round 0010/50 | Active=[0, 2] | Train ACC=90.31%  Val ACC=90.08%  Test ACC=78.17%  Test BACC=78.06%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 11
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 11 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.936481
#     net.0.bias                               | norm = 0.001795
#     net.1.weight                             | norm = 7.780564
#     net.1.bias                               | norm = 0.578411
#     net.3.weight                             | norm = 3.084554
#     net.3.bias                               | norm = 0.344830
#   [*] Best model saved (ACC=81.73%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 12
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 12 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.900163
#     net.0.bias                               | norm = 0.000306
#     net.1.weight                             | norm = 7.444453
#     net.1.bias                               | norm = 0.610408
#     net.3.weight                             | norm = 3.094700
#     net.3.bias                               | norm = 0.358693
#
#   Round 0012/50 | Active=[0, 1] | Train ACC=91.30%  Val ACC=89.45%  Test ACC=78.93%  Test BACC=78.73%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 13
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 13 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.900063
#     net.0.bias                               | norm = 0.002386
#     net.1.weight                             | norm = 7.232832
#     net.1.bias                               | norm = 0.622664
#     net.3.weight                             | norm = 3.065267
#     net.3.bias                               | norm = 0.358629
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 14
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 14 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.890664
#     net.0.bias                               | norm = 0.000630
#     net.1.weight                             | norm = 6.890756
#     net.1.bias                               | norm = 0.666768
#     net.3.weight                             | norm = 3.151901
#     net.3.bias                               | norm = 0.377133
#   [*] Best model saved (ACC=81.98%)
#
#   Round 0014/50 | Active=[0, 2] | Train ACC=89.14%  Val ACC=85.48%  Test ACC=81.98%  Test BACC=82.77%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 15
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 15 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.886472
#     net.0.bias                               | norm = 0.002009
#     net.1.weight                             | norm = 6.679879
#     net.1.bias                               | norm = 0.688254
#     net.3.weight                             | norm = 3.130313
#     net.3.bias                               | norm = 0.385428
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 16
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 16 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.861296
#     net.0.bias                               | norm = 0.000044
#     net.1.weight                             | norm = 6.469805
#     net.1.bias                               | norm = 0.715558
#     net.3.weight                             | norm = 3.176035
#     net.3.bias                               | norm = 0.394728
#
#   Round 0016/50 | Active=[1, 2] | Train ACC=91.32%  Val ACC=87.36%  Test ACC=78.43%  Test BACC=78.10%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 17
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 17 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.869164
#     net.0.bias                               | norm = 0.000973
#     net.1.weight                             | norm = 6.130848
#     net.1.bias                               | norm = 0.756619
#     net.3.weight                             | norm = 3.167500
#     net.3.bias                               | norm = 0.400564
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 18
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 18 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.880444
#     net.0.bias                               | norm = 0.000069
#     net.1.weight                             | norm = 5.802686
#     net.1.bias                               | norm = 0.786282
#     net.3.weight                             | norm = 3.163347
#     net.3.bias                               | norm = 0.418872
#
#   Round 0018/50 | Active=[0, 1] | Train ACC=89.31%  Val ACC=86.37%  Test ACC=79.70%  Test BACC=79.69%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 19
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 19 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.811933
#     net.0.bias                               | norm = 0.000175
#     net.1.weight                             | norm = 5.478013
#     net.1.bias                               | norm = 0.833628
#     net.3.weight                             | norm = 3.207634
#     net.3.bias                               | norm = 0.431777
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 20
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 20 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.804561
#     net.0.bias                               | norm = 0.000102
#     net.1.weight                             | norm = 5.153933
#     net.1.bias                               | norm = 0.874241
#     net.3.weight                             | norm = 3.214923
#     net.3.bias                               | norm = 0.452716
#
#   Round 0020/50 | Active=[0, 1] | Train ACC=89.73%  Val ACC=87.05%  Test ACC=79.95%  Test BACC=79.75%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 21
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 21 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.796115
#     net.0.bias                               | norm = 0.001468
#     net.1.weight                             | norm = 4.949147
#     net.1.bias                               | norm = 0.902967
#     net.3.weight                             | norm = 3.218735
#     net.3.bias                               | norm = 0.456399
#   [*] Best model saved (ACC=82.74%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 22
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 22 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.787228
#     net.0.bias                               | norm = 0.000421
#     net.1.weight                             | norm = 4.638024
#     net.1.bias                               | norm = 0.938058
#     net.3.weight                             | norm = 3.160006
#     net.3.bias                               | norm = 0.464685
#
#   Round 0022/50 | Active=[0, 1] | Train ACC=88.65%  Val ACC=83.74%  Test ACC=78.17%  Test BACC=78.13%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 23
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 23 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.716995
#     net.0.bias                               | norm = 0.000689
#     net.1.weight                             | norm = 4.328705
#     net.1.bias                               | norm = 0.989696
#     net.3.weight                             | norm = 3.265830
#     net.3.bias                               | norm = 0.490444
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 24
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 24 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.700862
#     net.0.bias                               | norm = 0.000103
#     net.1.weight                             | norm = 4.043037
#     net.1.bias                               | norm = 1.044343
#     net.3.weight                             | norm = 3.317173
#     net.3.bias                               | norm = 0.513511
#
#   Round 0024/50 | Active=[0, 1] | Train ACC=87.66%  Val ACC=86.37%  Test ACC=82.49%  Test BACC=83.33%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 25
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 25 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.682727
#     net.0.bias                               | norm = 0.001683
#     net.1.weight                             | norm = 3.869487
#     net.1.bias                               | norm = 1.088056
#     net.3.weight                             | norm = 3.318951
#     net.3.bias                               | norm = 0.526814
#   [*] Best model saved (ACC=83.25%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 26
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 26 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.706647
#     net.0.bias                               | norm = 0.001159
#     net.1.weight                             | norm = 3.710516
#     net.1.bias                               | norm = 1.111191
#     net.3.weight                             | norm = 3.301355
#     net.3.bias                               | norm = 0.537138
#
#   Round 0026/50 | Active=[1, 2] | Train ACC=88.32%  Val ACC=86.83%  Test ACC=81.73%  Test BACC=82.20%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 27
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 27 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.713542
#     net.0.bias                               | norm = 0.000712
#     net.1.weight                             | norm = 3.494677
#     net.1.bias                               | norm = 1.173697
#     net.3.weight                             | norm = 3.289692
#     net.3.bias                               | norm = 0.551254
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 28
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 28 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.647596
#     net.0.bias                               | norm = 0.000684
#     net.1.weight                             | norm = 3.347012
#     net.1.bias                               | norm = 1.212351
#     net.3.weight                             | norm = 3.318081
#     net.3.bias                               | norm = 0.568236
#
#   Round 0028/50 | Active=[0, 2] | Train ACC=86.71%  Val ACC=83.84%  Test ACC=80.71%  Test BACC=80.98%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 29
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 29 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.603921
#     net.0.bias                               | norm = 0.000672
#     net.1.weight                             | norm = 3.238673
#     net.1.bias                               | norm = 1.246590
#     net.3.weight                             | norm = 3.331484
#     net.3.bias                               | norm = 0.579496
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 30
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 30 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.626218
#     net.0.bias                               | norm = 0.000079
#     net.1.weight                             | norm = 3.162336
#     net.1.bias                               | norm = 1.258554
#     net.3.weight                             | norm = 3.320086
#     net.3.bias                               | norm = 0.597277
#
#   Round 0030/50 | Active=[0, 1] | Train ACC=87.51%  Val ACC=82.18%  Test ACC=81.22%  Test BACC=81.65%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 31
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 31 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.647189
#     net.0.bias                               | norm = 0.000811
#     net.1.weight                             | norm = 3.100333
#     net.1.bias                               | norm = 1.279547
#     net.3.weight                             | norm = 3.268687
#     net.3.bias                               | norm = 0.604538
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 32
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 32 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.642117
#     net.0.bias                               | norm = 0.001808
#     net.1.weight                             | norm = 3.087762
#     net.1.bias                               | norm = 1.290016
#     net.3.weight                             | norm = 3.329372
#     net.3.bias                               | norm = 0.610644
#
#   Round 0032/50 | Active=[1, 2] | Train ACC=86.95%  Val ACC=81.36%  Test ACC=82.99%  Test BACC=83.66%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 33
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 33 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.590983
#     net.0.bias                               | norm = 0.000701
#     net.1.weight                             | norm = 3.056015
#     net.1.bias                               | norm = 1.303557
#     net.3.weight                             | norm = 3.321695
#     net.3.bias                               | norm = 0.611464
#   [*] Best model saved (ACC=83.50%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 34
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 34 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.605489
#     net.0.bias                               | norm = 0.000163
#     net.1.weight                             | norm = 3.032564
#     net.1.bias                               | norm = 1.292611
#     net.3.weight                             | norm = 3.304055
#     net.3.bias                               | norm = 0.615132
#
#   Round 0034/50 | Active=[0, 1] | Train ACC=85.66%  Val ACC=81.34%  Test ACC=81.47%  Test BACC=82.00%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 35
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 35 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.618642
#     net.0.bias                               | norm = 0.000190
#     net.1.weight                             | norm = 2.985526
#     net.1.bias                               | norm = 1.285417
#     net.3.weight                             | norm = 3.245680
#     net.3.bias                               | norm = 0.611435
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 36
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 36 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.629202
#     net.0.bias                               | norm = 0.002221
#     net.1.weight                             | norm = 3.000578
#     net.1.bias                               | norm = 1.311192
#     net.3.weight                             | norm = 3.323913
#     net.3.bias                               | norm = 0.618115
#
#   Round 0036/50 | Active=[1, 2] | Train ACC=87.80%  Val ACC=82.95%  Test ACC=83.50%  Test BACC=83.95%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 37
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 37 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.607097
#     net.0.bias                               | norm = 0.000738
#     net.1.weight                             | norm = 2.987245
#     net.1.bias                               | norm = 1.323891
#     net.3.weight                             | norm = 3.328742
#     net.3.bias                               | norm = 0.625432
#   [*] Best model saved (ACC=83.76%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 38
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 38 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.611076
#     net.0.bias                               | norm = 0.000720
#     net.1.weight                             | norm = 2.979268
#     net.1.bias                               | norm = 1.320191
#     net.3.weight                             | norm = 3.285188
#     net.3.bias                               | norm = 0.628055
#
#   Round 0038/50 | Active=[0, 2] | Train ACC=87.41%  Val ACC=83.42%  Test ACC=81.98%  Test BACC=82.50%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 39
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 39 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.573621
#     net.0.bias                               | norm = 0.000710
#     net.1.weight                             | norm = 2.966487
#     net.1.bias                               | norm = 1.325450
#     net.3.weight                             | norm = 3.246951
#     net.3.bias                               | norm = 0.631410
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 40
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 40 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.590671
#     net.0.bias                               | norm = 0.000031
#     net.1.weight                             | norm = 2.956805
#     net.1.bias                               | norm = 1.328303
#     net.3.weight                             | norm = 3.305455
#     net.3.bias                               | norm = 0.637594
#
#   Round 0040/50 | Active=[0, 1] | Train ACC=86.07%  Val ACC=80.31%  Test ACC=80.46%  Test BACC=80.82%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 41
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 41 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.607706
#     net.0.bias                               | norm = 0.000768
#     net.1.weight                             | norm = 2.956361
#     net.1.bias                               | norm = 1.336665
#     net.3.weight                             | norm = 3.325744
#     net.3.bias                               | norm = 0.644364
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 42
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 42 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.568960
#     net.0.bias                               | norm = 0.000729
#     net.1.weight                             | norm = 2.965121
#     net.1.bias                               | norm = 1.336680
#     net.3.weight                             | norm = 3.345308
#     net.3.bias                               | norm = 0.646395
#
#   Round 0042/50 | Active=[0, 2] | Train ACC=85.79%  Val ACC=84.07%  Test ACC=82.23%  Test BACC=82.93%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 43
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 43 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.620628
#     net.0.bias                               | norm = 0.001897
#     net.1.weight                             | norm = 2.956126
#     net.1.bias                               | norm = 1.326564
#     net.3.weight                             | norm = 3.301075
#     net.3.bias                               | norm = 0.646221
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 44
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 44 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.561139
#     net.0.bias                               | norm = 0.000914
#     net.1.weight                             | norm = 2.955823
#     net.1.bias                               | norm = 1.314274
#     net.3.weight                             | norm = 3.302506
#     net.3.bias                               | norm = 0.642706
#
#   Round 0044/50 | Active=[0, 2] | Train ACC=85.84%  Val ACC=82.59%  Test ACC=82.74%  Test BACC=83.79%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 45
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 45 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.571065
#     net.0.bias                               | norm = 0.000053
#     net.1.weight                             | norm = 2.930943
#     net.1.bias                               | norm = 1.321710
#     net.3.weight                             | norm = 3.257255
#     net.3.bias                               | norm = 0.645634
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 46
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 46 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.593367
#     net.0.bias                               | norm = 0.001411
#     net.1.weight                             | norm = 2.942268
#     net.1.bias                               | norm = 1.332447
#     net.3.weight                             | norm = 3.289276
#     net.3.bias                               | norm = 0.647490
#
#   Round 0046/50 | Active=[1, 2] | Train ACC=86.88%  Val ACC=80.51%  Test ACC=82.99%  Test BACC=83.54%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 47
#   Active clients : [0, 2]  |  Skipped: client_1
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 2
#
#   Round 47 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.621953
#     net.0.bias                               | norm = 0.000943
#     net.1.weight                             | norm = 2.929990
#     net.1.bias                               | norm = 1.317631
#     net.3.weight                             | norm = 3.280305
#     net.3.bias                               | norm = 0.639354
#   [*] Best model saved (ACC=84.01%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 48
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 48 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.613574
#     net.0.bias                               | norm = 0.001561
#     net.1.weight                             | norm = 2.947109
#     net.1.bias                               | norm = 1.317101
#     net.3.weight                             | norm = 3.303783
#     net.3.bias                               | norm = 0.644707
#
#   Round 0048/50 | Active=[1, 2] | Train ACC=87.24%  Val ACC=79.83%  Test ACC=81.73%  Test BACC=82.10%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 49
#   Active clients : [0, 1]  |  Skipped: client_2
#   TRAINING CLIENT : 0
#   TRAINING CLIENT : 1
#
#   Round 49 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.605844
#     net.0.bias                               | norm = 0.000269
#     net.1.weight                             | norm = 2.913861
#     net.1.bias                               | norm = 1.307003
#     net.3.weight                             | norm = 3.258441
#     net.3.bias                               | norm = 0.647124
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 50
#   Active clients : [1, 2]  |  Skipped: client_0
#   TRAINING CLIENT : 1
#   TRAINING CLIENT : 2
#
#   Round 50 | Global Attention Weight Norms:
#     net.0.weight                             | norm = 1.622340
#     net.0.bias                               | norm = 0.001092
#     net.1.weight                             | norm = 2.929278
#     net.1.bias                               | norm = 1.321051
#     net.3.weight                             | norm = 3.303354
#     net.3.bias                               | norm = 0.647221
#
#   Round 0050/50 | Active=[1, 2] | Train ACC=87.44%  Val ACC=78.76%  Test ACC=82.99%  Test BACC=83.52%
#
# =================================================================
#   Client Participation Summary
# =================================================================
#   client_0 : trained for 34 epoch(s) across 34 round(s)
#   client_1 : trained for 29 epoch(s) across 29 round(s)
#   client_2 : trained for 37 epoch(s) across 37 round(s)
# Best test ACC (checkpoint): 84.01%
# Saved: history.json | training_log.json | participation_log.json

# %%
import matplotlib.pyplot as plt

rounds = history["rounds"]

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# ── ACC plot ──────────────────────────────────────────────────────────────────
ax = axes[0]
ax.plot(rounds, history["train_acc"], label="Train ACC",  color="steelblue",  linewidth=2)
ax.plot(rounds, history["val_acc"],   label="Val ACC",    color="darkorange",  linewidth=2)
ax.plot(rounds, history["test_acc"],  label="Test ACC (C3)", color="green",   linewidth=2)
ax.set_xlabel("FL Round", fontsize=13)
ax.set_ylabel("Accuracy (%)", fontsize=13)
ax.set_title("Accuracy per FL Round", fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
ax.set_xlim(1, ROUNDS)
ax.set_ylim(0, 100)

# ── BACC plot ─────────────────────────────────────────────────────────────────
ax = axes[1]
ax.plot(rounds, history["train_bacc"], label="Train BACC",     color="steelblue",  linewidth=2)
ax.plot(rounds, history["val_bacc"],   label="Val BACC",       color="darkorange",  linewidth=2)
ax.plot(rounds, history["test_bacc"],  label="Test BACC (C3)", color="green",       linewidth=2)
ax.set_xlabel("FL Round", fontsize=13)
ax.set_ylabel("Balanced Accuracy (%)", fontsize=13)
ax.set_title("Balanced Accuracy per FL Round", fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
ax.set_xlim(1, ROUNDS)
ax.set_ylim(0, 100)

plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/training_curves.png", dpi=150, bbox_inches="tight")
plt.show()
print(f"Plot saved to {OUTPUT_DIR}/training_curves.png")
# Out:
# Plot saved to /content/drive/MyDrive/FACMIC/outputs_inactive/training_curves.png

# %%
# Load best checkpoint
global_attention.load_state_dict(
    torch.load(f"{OUTPUT_DIR}/best_attention.pt", map_location=device)
)

print("=" * 55)
print("  Final Results — best checkpoint on client_3 test set")
print("=" * 55)
acc, bacc = evaluate(global_attention, test_loader)
print(f"  Test  ACC  = {acc:.2f}%")
print(f"  Test  BACC = {bacc:.2f}%")

print("\n  Validation on training clients:")
for cid, vl in enumerate(val_loaders):
    vacc, vbacc = evaluate(global_attention, vl)
    print(f"    client_{cid}  ACC={vacc:.2f}%  BACC={vbacc:.2f}%")

# Best round from history
best_round = history["rounds"][
    int(np.argmax(history["test_acc"]))
]
print(f"\n  Best test ACC achieved at round {best_round}")
# Out:
# =======================================================
#   Final Results — best checkpoint on client_3 test set
# =======================================================
#   Test  ACC  = 84.01%
#   Test  BACC = 84.50%
#
#   Validation on training clients:
#     client_0  ACC=82.88%  BACC=83.15%
#     client_1  ACC=75.61%  BACC=76.25%
#     client_2  ACC=81.91%  BACC=81.27%
#
#   Best test ACC achieved at round 47

# %%
# Participation summary
print("\n" + "=" * 55)
print("  Client Participation Summary")
print("=" * 55)
print(f"  {'Client':<12} {'Rounds Selected':>16} {'Epochs Trained':>15} {'Selection Rate':>15}")
print("  " + "-" * 60)
for cid in range(3):
    r_sel  = rounds_trained[cid] // EPOCHS
    e_tot  = rounds_trained[cid]
    rate   = 100 * r_sel / ROUNDS
    print(f"  client_{cid}    {r_sel:>16}     {e_tot:>14}     {rate:>13.1f}%")

# Show which rounds each client was active
print("\n  Round-by-round active clients:")
for r, ac in zip(history["rounds"], history["active_clients"]):
    skipped = [c for c in range(3) if c not in ac][0]
    print(f"    Round {r:03d}: active={ac}  skipped=client_{skipped}")
# Out:
# =======================================================
#   Client Participation Summary
# =======================================================
#   Client        Rounds Selected  Epochs Trained  Selection Rate
#   ------------------------------------------------------------
#   client_0                  34                 34              68.0%
#   client_1                  29                 29              58.0%
#   client_2                  37                 37              74.0%
#
#   Round-by-round active clients:
#     Round 001: active=[0, 2]  skipped=client_1
#     Round 002: active=[0, 1]  skipped=client_2
#     Round 003: active=[0, 2]  skipped=client_1
#     Round 004: active=[0, 2]  skipped=client_1
#     Round 005: active=[0, 2]  skipped=client_1
#     Round 006: active=[1, 2]  skipped=client_0
#     Round 007: active=[0, 2]  skipped=client_1
#     Round 008: active=[0, 2]  skipped=client_1
#     Round 009: active=[0, 2]  skipped=client_1
#     Round 010: active=[0, 2]  skipped=client_1
#     Round 011: active=[1, 2]  skipped=client_0
#     Round 012: active=[0, 1]  skipped=client_2
#     Round 013: active=[1, 2]  skipped=client_0
#     Round 014: active=[0, 2]  skipped=client_1
#     Round 015: active=[1, 2]  skipped=client_0
#     Round 016: active=[1, 2]  skipped=client_0
#     Round 017: active=[0, 2]  skipped=client_1
#     Round 018: active=[0, 1]  skipped=client_2
#     Round 019: active=[0, 1]  skipped=client_2
#     Round 020: active=[0, 1]  skipped=client_2
#     Round 021: active=[1, 2]  skipped=client_0
#     Round 022: active=[0, 1]  skipped=client_2
#     Round 023: active=[0, 2]  skipped=client_1
#     Round 024: active=[0, 1]  skipped=client_2
#     Round 025: active=[1, 2]  skipped=client_0
#     Round 026: active=[1, 2]  skipped=client_0
#     Round 027: active=[0, 2]  skipped=client_1
#     Round 028: active=[0, 2]  skipped=client_1
#     Round 029: active=[0, 2]  skipped=client_1
#     Round 030: active=[0, 1]  skipped=client_2
#     Round 031: active=[0, 2]  skipped=client_1
#     Round 032: active=[1, 2]  skipped=client_0
#     Round 033: active=[1, 2]  skipped=client_0
#     Round 034: active=[0, 1]  skipped=client_2
#     Round 035: active=[0, 1]  skipped=client_2
#     Round 036: active=[1, 2]  skipped=client_0
#     Round 037: active=[0, 2]  skipped=client_1
#     Round 038: active=[0, 2]  skipped=client_1
#     Round 039: active=[0, 2]  skipped=client_1
#     Round 040: active=[0, 1]  skipped=client_2
#     Round 041: active=[1, 2]  skipped=client_0
#     Round 042: active=[0, 2]  skipped=client_1
#     Round 043: active=[1, 2]  skipped=client_0
#     Round 044: active=[0, 2]  skipped=client_1
#     Round 045: active=[0, 1]  skipped=client_2
#     Round 046: active=[1, 2]  skipped=client_0
#     Round 047: active=[0, 2]  skipped=client_1
#     Round 048: active=[1, 2]  skipped=client_0
#     Round 049: active=[0, 1]  skipped=client_2
#     Round 050: active=[1, 2]  skipped=client_0
