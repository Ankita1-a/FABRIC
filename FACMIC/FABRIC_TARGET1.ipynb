# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# FACMIC with BiomedCLIP — Federated Adaptive CLIP Model for Medical Image Classification
# ========================================================================================
# Training clients  : client_0, client_2, client_3 \
# Target domain     : client_1  (used UNLABELLED for LMMD domain adaptation) \
# Test set          : client_1  (evaluated with labels after training)
#
# Design follows the FACMIC paper (Wu et al., MICCAI):\
#   • Frozen BiomedCLIP encoders \
#   • Lightweight 5-layer feature-attention module per client\
#   • Contrastive loss   Lcontr  \
#   • LMMD domain-adaptation loss  LDA  — source = each training\
#     client, target = client_1 images (no labels used)\
#   • FedAVG weighted aggregation of attention parameters only  \
#   • Dynamic per-image text prompts from llm_prompts_1.json;\
#     class-level fallback when an image has no JSON entry
#
# Requirements
# ------------
# pip install open_clip_torch torch torchvision scikit-learn Pillow tqdm

# %%
# !pip install open_clip_torch torch torchvision scikit-learn Pillow tqdm
# Out:
# Collecting open_clip_torch
#   Downloading open_clip_torch-3.3.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cu128)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (2025.11.3)
# Collecting ftfy (from open_clip_torch)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (1.10.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.7.0)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (1.0.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.17->open_clip_torch) (6.0.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open_clip_torch) (0.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (26.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (0.24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->open_clip_torch) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open_clip_torch) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->open_clip_torch) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->open_clip_torch) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub->open_clip_torch) (0.1.2)
# Downloading open_clip_torch-3.3.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.4 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: ftfy, open_clip_torch
# Successfully installed ftfy-6.3.1 open_clip_torch-3.3.0

# %%
import argparse
import copy
import json
import os
import random
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm

import open_clip

# %%
# ────────────────────────────────────────────────────────────────────────────
# Constants & reproducibility
# ────────────────────────────────────────────────────────────────────────────
CLASS_NAMES = ["glioma_tumor", "meningioma_tumor", "no_tumor", "pituitary_tumor"]
CLASS2IDX   = {c: i for i, c in enumerate(CLASS_NAMES)}

# Fallback prompts when an image path is absent from llm_prompts_1.json
FALLBACK_PROMPTS = {
    "glioma_tumor":     "brain MRI showing glioma tumor",
    "meningioma_tumor": "brain MRI showing meningioma tumor",
    "no_tumor":         "brain MRI showing no tumor",
    "pituitary_tumor":  "brain MRI showing pituitary tumor",
}


def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
DATA_ROOT    = "/content/drive/MyDrive/FACMIC/data/BrainTumor"
PROMPTS_JSON = "/content/drive/MyDrive/FACMIC/llm_prompts_1.json"
OUTPUT_DIR   = "/content/drive/MyDrive/FACMIC/outputs_target_client_1"

# ── Hyperparameters ──────────────────────────────────────────────────────────
ROUNDS       = 50
EPOCHS       = 1       # local epochs per round
BATCH_SIZE   = 32
LR           = 0.001
LMMD_LAMBDA  = 1.0
TEMPERATURE  = 0.07
EVAL_EVERY   = 2
SEED         = 42
# ────────────────────────────────────────────────────────────────────────────

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
print("Loading BiomedCLIP ...")
biomedclip, _, preprocess = open_clip.create_model_and_transforms(
    "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
)
tokenizer = open_clip.get_tokenizer(
    "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
)
biomedclip = biomedclip.to(device).eval()
for p in biomedclip.parameters():
    p.requires_grad_(False)

# Infer feature dimension
with torch.no_grad():
    FEAT_DIM = biomedclip.encode_image(
        torch.zeros(1, 3, 224, 224, device=device)
    ).shape[-1]

print(f"BiomedCLIP loaded. Feature dim = {FEAT_DIM}")
# Out:
# Loading BiomedCLIP ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# open_clip_config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/784M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# BiomedCLIP loaded. Feature dim = 512

# %%
# ────────────────────────────────────────────────────────────────────────────
# BiomedCLIP loader
# ────────────────────────────────────────────────────────────────────────────
def load_biomedclip(device: torch.device):
    """
    Load Microsoft BiomedCLIP-PubMedBERT-256-vit_L_14 via open_clip.
    Returns (model, tokenizer, preprocess_val).
    All BiomedCLIP parameters are frozen — only the attention module trains.
    """
    model, _, preprocess_val = open_clip.create_model_and_transforms(
        "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
    )
    tokenizer = open_clip.get_tokenizer(
        "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
    )
    model = model.to(device).eval()
    for p in model.parameters():
        p.requires_grad_(False)
    return model, tokenizer, preprocess_val

# %%
# ────────────────────────────────────────────────────────────────────────────
# Datasets
# ────────────────────────────────────────────────────────────────────────────
class BrainTumorDataset(Dataset):
    """
    Labelled dataset for a single client directory.

    Directory layout:
        <client_dir>/
            glioma_tumor/     *.jpg
            meningioma_tumor/ *.jpg
            no_tumor/         *.jpg
            pituitary_tumor/  *.jpg

    Parameters
    ----------
    client_dir : str   — path to the client folder
    prompts    : dict  — {json_path_key: prompt_string}
    transform          — open_clip / torchvision preprocessing
    split      : str   — 'train' | 'val' | 'test'  (80 / 10 / 10 per class)
    seed       : int
    """

    def __init__(
        self,
        client_dir: str,
        prompts: Dict[str, str],
        transform,
        split: str = "train",
        seed: int = 42,
    ):
        self.transform = transform
        self.prompts   = prompts
        # (abs_path, label_int, prompt_string)
        self.samples: List[Tuple[str, int, str]] = []

        for cls_name in CLASS_NAMES:
            cls_dir = Path(client_dir) / cls_name
            if not cls_dir.exists():
                continue
            files = sorted(
                p for p in cls_dir.iterdir()
                if p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp"}
            )
            rng = random.Random(seed)
            rng.shuffle(files)
            n       = len(files)
            n_train = int(0.8 * n)
            n_val   = int(0.1 * n)
            if (split=='train') or (split=='val'):
                splits  = {
                    "train": files[:n_train],
                    "val":   files[n_train : n_train + n_val],
                    "test":  files[n_train + n_val :],
                }
            else:
                splits  = {
                    "test":  files
                }
            for fpath in splits[split]:
                prompt = self._resolve_prompt(fpath, cls_name)
                self.samples.append((str(fpath), CLASS2IDX[cls_name], prompt))

    def _resolve_prompt(self, fpath: Path, cls_name: str) -> str:
        """Match by filename; fall back to class-level prompt."""
        stem = fpath.name
        for key, val in self.prompts.items():
            if key.endswith(stem):
                return val
        return FALLBACK_PROMPTS[cls_name]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label, prompt = self.samples[idx]
        img = Image.open(path).convert("RGB")
        return self.transform(img), label, prompt


class UnlabelledDataset(Dataset):
    """
    Loads images from a directory WITHOUT labels.
    Used for client_3 as the LMMD target domain during training.
    Only the train split (50 %:50%) is used so the test images stay unseen.
    """

    def __init__(self, client_dir: str, transform, seed: int = 42):
        self.transform = transform
        self.paths: List[str] = []

        for cls_name in CLASS_NAMES:
            cls_dir = Path(client_dir) / cls_name
            if not cls_dir.exists():
                continue
            files = sorted(
                p for p in cls_dir.iterdir()
                if p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp"}
            )
            rng = random.Random(seed)
            rng.shuffle(files)
            n_train = len(files)
            # Only train-split images — test images must stay completely unseen
            self.paths.extend(str(f) for f in files[:n_train])

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert("RGB")
        return self.transform(img)   # no label, no prompt

# %%
with open(PROMPTS_JSON) as f:
    prompts_dict = json.load(f)
print(f"Loaded {len(prompts_dict)} prompts.")

root              = Path(DATA_ROOT)
train_client_dirs = [str(root / f"client_{i}") for i in [0, 2, 3]]
target_dir        = str(root / "client_1")

train_loaders, val_loaders = [], []
for cd in train_client_dirs:
    ds_tr = BrainTumorDataset(cd, prompts_dict, preprocess, "train", SEED)
    ds_va = BrainTumorDataset(cd, prompts_dict, preprocess, "val",   SEED)
    train_loaders.append(DataLoader(ds_tr, batch_size=BATCH_SIZE,
                                    shuffle=True,  num_workers=2,
                                    pin_memory=True, drop_last=True))
    val_loaders.append( DataLoader(ds_va, batch_size=BATCH_SIZE,
                                    shuffle=False, num_workers=2,
                                    pin_memory=True))

target_loader = DataLoader(
    UnlabelledDataset(target_dir, preprocess, SEED),
    batch_size=BATCH_SIZE, shuffle=True,
    num_workers=2, pin_memory=True, drop_last=True,
)
test_loader = DataLoader(
    BrainTumorDataset(target_dir, prompts_dict, preprocess, "test", SEED),
    batch_size=BATCH_SIZE, shuffle=False,
    num_workers=2, pin_memory=True,
)

train_sizes = [len(dl.dataset) for dl in train_loaders]
print(f"Train sizes         : {train_sizes}")
print(f"Target (C1) unlabelled : {len(target_loader.dataset)}")
print(f"Test   (C1) labelled   : {len(test_loader.dataset)}")
# Out:
# Loaded 3244 prompts.
# Train sizes         : [1180, 758, 315]
# Target (C1) unlabelled : 425
# Test   (C1) labelled   : 425

# %%
train_client_dirs
# Out:
# ['/content/drive/MyDrive/FACMIC/data/BrainTumor/client_0',
#  '/content/drive/MyDrive/FACMIC/data/BrainTumor/client_2',
#  '/content/drive/MyDrive/FACMIC/data/BrainTumor/client_3']

# %%
# ────────────────────────────────────────────────────────────────────────────
# Feature-Attention Module
# ────────────────────────────────────────────────────────────────────────────
class FeatureAttentionModule(nn.Module):
    """
    ai(·) : R^D -> [0,1]^D
    Linear -> BN -> LeakyReLU -> Linear -> Softmax
    Only this module is trained and communicated between clients and server.
    """

    def __init__(self, feat_dim: int):
        super().__init__()
        hidden = max(feat_dim // 4, 64)
        self.net = nn.Sequential(
            nn.Linear(feat_dim, hidden),
            nn.BatchNorm1d(hidden),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Linear(hidden, feat_dim),
            nn.Softmax(dim=-1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """x: (B, D) -> masked features (B, D)"""
        return self.net(x) * x   # Hadamard product

# %%
# ────────────────────────────────────────────────────────────────────────────
# Contrastive loss
# ────────────────────────────────────────────────────────────────────────────
def contrastive_loss(
    img_feats: torch.Tensor,   # (B, D)
    txt_feats: torch.Tensor,   # (B, D)
    temperature: float = 0.07,
) -> torch.Tensor:
    """
    Symmetric cross-entropy over the B x B cosine-similarity matrix.
    Lcontr = -1/B sum_j 1/2 [log p_jj + log q_jj]
    """
    img_n  = F.normalize(img_feats, dim=-1)
    txt_n  = F.normalize(txt_feats, dim=-1)
    S      = img_n @ txt_n.T / temperature
    labels = torch.arange(S.size(0), device=S.device)
    return (F.cross_entropy(S, labels) + F.cross_entropy(S.T, labels)) / 2.0

# %%
# ────────────────────────────────────────────────────────────────────────────
# LMMD loss
# ────────────────────────────────────────────────────────────────────────────
def gaussian_kernel(
    x: torch.Tensor,
    y: torch.Tensor,
    bandwidth: Optional[float] = None,
) -> torch.Tensor:
    diff = x.unsqueeze(1) - y.unsqueeze(0)   # (n, m, D)
    sq   = (diff ** 2).sum(-1)               # (n, m)
    if bandwidth is None:
        bandwidth = sq.detach().median().clamp(min=1e-6).item()
    return torch.exp(-sq / (2.0 * bandwidth))

def lmmd_loss(
    src_feats:   torch.Tensor,   # (ns, D)  masked source (training client)
    tgt_feats:   torch.Tensor,   # (nt, D)  masked target (client_3, no labels)
    src_labels:  torch.Tensor,   # (ns,)    integer class labels
    tgt_probs:   torch.Tensor,   # (nt, K)  pseudo-label probabilities
    num_classes: int,
    bandwidth:   Optional[float] = None,
) -> torch.Tensor:
    """
    Local Maximum Mean Discrepancy.
    Source Ds = current training client (labelled).
    Target Dt = client_3 images (unlabelled, pseudo-labelled via Eq. 3).
    """
    K_ss = gaussian_kernel(src_feats, src_feats, bandwidth)
    K_tt = gaussian_kernel(tgt_feats, tgt_feats, bandwidth)
    K_st = gaussian_kernel(src_feats, tgt_feats, bandwidth)

    loss = torch.tensor(0.0, device=src_feats.device)

    for c in range(num_classes):
        # Source: hard label weights
        src_mask = (src_labels == c).float()
        ws = src_mask / src_mask.sum().clamp(min=1e-6)

        # Target: soft pseudo-label weights
        wt = tgt_probs[:, c]
        wt = wt / wt.sum().clamp(min=1e-6)

        term_ss = (ws.unsqueeze(1) * ws.unsqueeze(0) * K_ss).sum()
        term_tt = (wt.unsqueeze(1) * wt.unsqueeze(0) * K_tt).sum()
        term_st = (ws.unsqueeze(1) * wt.unsqueeze(0) * K_st).sum()

        loss += term_ss + term_tt - 2.0 * term_st

    return loss / num_classes

# %%
# ────────────────────────────────────────────────────────────────────────────
# Helpers: encoding & prediction
# ────────────────────────────────────────────────────────────────────────────
@torch.no_grad()
def encode_class_prompts():
    tokens = tokenizer([FALLBACK_PROMPTS[c] for c in CLASS_NAMES]).to(device)
    return F.normalize(biomedclip.encode_text(tokens), dim=-1)

@torch.no_grad()
def encode_batch_prompts(prompts):
    tokens = tokenizer(prompts).to(device)
    return F.normalize(biomedclip.encode_text(tokens), dim=-1)

@torch.no_grad()
def predict_probs(masked_img_feats, class_txt_feats, temperature=0.07):
    img_n = F.normalize(masked_img_feats, dim=-1)
    txt_n = F.normalize(class_txt_feats,  dim=-1)
    return F.softmax(img_n @ txt_n.T / temperature, dim=-1)
# Pre-compute class text features once
class_txt_feats = encode_class_prompts()
print(f"Class text features shape: {class_txt_feats.shape}")
# Out:
# Class text features shape: torch.Size([4, 512])

# %%
# ────────────────────────────────────────────────────────────────────────────
# One local training epoch
# ────────────────────────────────────────────────────────────────────────────
def local_train_epoch(attention_module, optimizer,
                      train_loader, tgt_iter_state):
    attention_module.train()
    total_loss, steps = 0.0, 0
    tgt_iter = tgt_iter_state["iter"]

    for imgs, labels, prompts in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)

        with torch.no_grad():
            src_raw = biomedclip.encode_image(imgs) # Passing image through image encoder

        txt_feats  = encode_batch_prompts(list(prompts)) # Passing prompts through text encoder
        masked_src = attention_module(src_raw)
        l_contr    = contrastive_loss(masked_src, txt_feats, TEMPERATURE)

        try:
            tgt_imgs = next(tgt_iter)
        except StopIteration:
            tgt_iter = iter(target_loader)
            tgt_iter_state["iter"] = tgt_iter
            tgt_imgs = next(tgt_iter)

        tgt_imgs = tgt_imgs.to(device)
        with torch.no_grad():
            tgt_raw    = biomedclip.encode_image(tgt_imgs)
            masked_tgt = attention_module(tgt_raw)
            tgt_probs  = predict_probs(masked_tgt, class_txt_feats, TEMPERATURE)

        l_da = lmmd_loss(masked_src.detach(), masked_tgt.detach(),
                         labels, tgt_probs, len(CLASS_NAMES))
        if imgs.size(0) < 16:
            l_da = l_da * 0.1

        loss = l_contr + LMMD_LAMBDA * l_da
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        steps      += 1

    return total_loss / max(steps, 1)

# %%
# ────────────────────────────────────────────────────────────────────────────
# Evaluation
# ────────────────────────────────────────────────────────────────────────────
@torch.no_grad()
def evaluate(attention_module, loader):
    attention_module.eval()
    all_preds, all_labels = [], []
    for imgs, labels, _ in loader:
        imgs   = imgs.to(device)
        masked = attention_module(biomedclip.encode_image(imgs))
        preds  = predict_probs(masked, class_txt_feats, TEMPERATURE).argmax(-1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
    acc  = accuracy_score(all_labels, all_preds) * 100.0
    bacc = balanced_accuracy_score(all_labels, all_preds) * 100.0
    return acc, bacc

@torch.no_grad()
def evaluate_train(attention_module, loader):
    """
    Evaluate on a training loader.
    Training loader has drop_last=True and shuffle=True — we just run one
    full pass over whatever batches are available.  No gradient, eval mode.
    """
    attention_module.eval()
    all_preds, all_labels = [], []
    for imgs, labels, _ in loader:
        imgs   = imgs.to(device)
        masked = attention_module(biomedclip.encode_image(imgs))
        preds  = predict_probs(masked, class_txt_feats, TEMPERATURE).argmax(-1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
    acc  = accuracy_score(all_labels, all_preds) * 100.0
    bacc = balanced_accuracy_score(all_labels, all_preds) * 100.0
    return acc, bacc

# %%
# ────────────────────────────────────────────────────────────────────────────
# FedAVG aggregation
# ────────────────────────────────────────────────────────────────────────────
def fedavg_aggregate(
    client_state_dicts: List[dict],
    client_sizes:       List[int],
) -> dict:

    total   = sum(client_sizes)
    weights = [s / total for s in client_sizes]
    agg     = copy.deepcopy(client_state_dicts[0])
    for key in agg:
        agg[key] = sum(
            w * sd[key].float()
            for w, sd in zip(weights, client_state_dicts)
        )
    return agg

# %%
global_attention = FeatureAttentionModule(FEAT_DIM).to(device)
best_acc         = 0.0

# ── Per-round history (one entry per round) ──────────────────────────────────
history = {
    # averaged across the 3 training clients each round
    "train_acc":  [], "train_bacc":  [],
    "val_acc":    [], "val_bacc":    [],
    # client_3 test set
    "test_acc":   [], "test_bacc":   [],
    "rounds":     [],
}

print("=" * 65)
print("  FACMIC-BiomedCLIP | Train: C0,C2,C3 | Target+Test: C1")
print("=" * 65)

for round_idx in range(1, ROUNDS + 1):
    print('-'*65)
    print(f"TRAINING FOR ROUND : {round_idx}")
    client_states          = []
    # collect per-client metrics before aggregation (on local model)
    round_train_accs,  round_train_baccs  = [], []
    round_val_accs,    round_val_baccs    = [], []

    # ── Local training ────────────────────────────────────────────────────────
    for i_ in range(len([0,2,3])):
        cid=[0,2,3][i_]
        print(f"TRAINING FOR CLIENT : {cid}")
        local_attn = FeatureAttentionModule(FEAT_DIM).to(device)
        local_attn.load_state_dict(copy.deepcopy(global_attention.state_dict()))

        optimizer = torch.optim.Adam(
            local_attn.parameters(), lr=LR,
            betas=(0.9, 0.98), weight_decay=0.02,
        )
        tgt_iter_state = {"iter": iter(target_loader)}

        for _ in range(EPOCHS):
            local_train_epoch(local_attn, optimizer,
                              train_loaders[i_], tgt_iter_state)

        # ── Evaluate this client's local model before aggregation ─────────────
        tr_acc,  tr_bacc  = evaluate_train(local_attn, train_loaders[i_])
        val_acc, val_bacc = evaluate(local_attn, val_loaders[i_])

        round_train_accs.append(tr_acc);   round_train_baccs.append(tr_bacc)
        round_val_accs.append(val_acc);    round_val_baccs.append(val_bacc)

        client_states.append(copy.deepcopy(local_attn.state_dict()))

    # ── FedAVG aggregation ────────────────────────────────────────────────────
    global_attention.load_state_dict(
        fedavg_aggregate(client_states, train_sizes)
    )
    param_norms = {}
    for name, param in global_attention.named_parameters():
        param_norms[name] = param.data.norm().item()

    print(f"\nRound {round_idx} | Global Attention Weight Norms:")
    for name, norm in param_norms.items():
        print(f"  {name:40s} | norm = {norm:.6f}")
    # ── Test evaluation (global model on client_3) ────────────────────────────
    test_acc, test_bacc = evaluate(global_attention, test_loader)

    # ── Average across clients and store ─────────────────────────────────────
    history["rounds"].append(round_idx)
    history["train_acc"].append(float(np.mean(round_train_accs)))
    history["train_bacc"].append(float(np.mean(round_train_baccs)))
    history["val_acc"].append(float(np.mean(round_val_accs)))
    history["val_bacc"].append(float(np.mean(round_val_baccs)))
    history["test_acc"].append(float(test_acc))
    history["test_bacc"].append(float(test_bacc))

    # ── Print every EVAL_EVERY rounds ─────────────────────────────────────────
    if round_idx % EVAL_EVERY == 0 or round_idx == ROUNDS:
        print(
            f"Round {round_idx:04d}/{ROUNDS} | "
            f"Train ACC={history['train_acc'][-1]:.2f}%  "
            f"Val ACC={history['val_acc'][-1]:.2f}%  "
            f"Test ACC={test_acc:.2f}%  "
            f"Test BACC={test_bacc:.2f}%"
        )

    # ── Save best checkpoint ───────────────────────────────────────────────────
    if test_acc > best_acc:
        best_acc = test_acc
        print(f"  [*] Best model saved (ACC={best_acc:.2f}%)")
        torch.save(global_attention.state_dict(),
                   f"{OUTPUT_DIR}/best_attention.pt")

# Save full history
with open(f"{OUTPUT_DIR}/history.json", "w") as f:
    json.dump(history, f, indent=2)
# Save results_log (lightweight — test only, mirrors original code)
results_log = [
    {"round": r, "acc": a, "bacc": b}
    for r, a, b in zip(history["rounds"], history["test_acc"], history["test_bacc"])
]
with open(f"{OUTPUT_DIR}/training_log.json", "w") as f:
    json.dump(results_log, f, indent=2)

print(f"Best client_1 test ACC: {best_acc:.2f}%")
print(f"Saved: history.json")
print(f"Saved: training_log.json")
# Out:
# =================================================================
#   FACMIC-BiomedCLIP | Train: C0,C2,C3 | Target+Test: C1
# =================================================================
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 1
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 1 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 5.193172
#   net.0.bias                               | norm = 0.094822
#   net.1.weight                             | norm = 11.001850
#   net.1.bias                               | norm = 0.114004
#   net.3.weight                             | norm = 8.983371
#   net.3.bias                               | norm = 0.779824
#   [*] Best model saved (ACC=79.76%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 2
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 2 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 4.015844
#   net.0.bias                               | norm = 0.003404
#   net.1.weight                             | norm = 10.689118
#   net.1.bias                               | norm = 0.217010
#   net.3.weight                             | norm = 5.866433
#   net.3.bias                               | norm = 0.521989
# Round 0002/50 | Train ACC=86.31%  Val ACC=81.20%  Test ACC=85.65%  Test BACC=85.75%
#   [*] Best model saved (ACC=85.65%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 3
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 3 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 3.282065
#   net.0.bias                               | norm = 0.000335
#   net.1.weight                             | norm = 10.376371
#   net.1.bias                               | norm = 0.296882
#   net.3.weight                             | norm = 4.057486
#   net.3.bias                               | norm = 0.375804
#   [*] Best model saved (ACC=88.24%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 4
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 4 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 2.833357
#   net.0.bias                               | norm = 0.000411
#   net.1.weight                             | norm = 10.064387
#   net.1.bias                               | norm = 0.348333
#   net.3.weight                             | norm = 3.406243
#   net.3.bias                               | norm = 0.318720
# Round 0004/50 | Train ACC=83.98%  Val ACC=80.47%  Test ACC=88.71%  Test BACC=88.61%
#   [*] Best model saved (ACC=88.71%)
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 5
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 5 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 2.516423
#   net.0.bias                               | norm = 0.000412
#   net.1.weight                             | norm = 9.752281
#   net.1.bias                               | norm = 0.384688
#   net.3.weight                             | norm = 3.144981
#   net.3.bias                               | norm = 0.296632
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 6
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 6 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 2.314106
#   net.0.bias                               | norm = 0.000421
#   net.1.weight                             | norm = 9.440565
#   net.1.bias                               | norm = 0.417095
#   net.3.weight                             | norm = 3.052385
#   net.3.bias                               | norm = 0.295332
# Round 0006/50 | Train ACC=84.38%  Val ACC=83.57%  Test ACC=87.53%  Test BACC=87.83%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 7
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 7 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 2.171180
#   net.0.bias                               | norm = 0.000416
#   net.1.weight                             | norm = 9.128345
#   net.1.bias                               | norm = 0.449725
#   net.3.weight                             | norm = 3.008914
#   net.3.bias                               | norm = 0.302606
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 8
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 8 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 2.051191
#   net.0.bias                               | norm = 0.000419
#   net.1.weight                             | norm = 8.816730
#   net.1.bias                               | norm = 0.481791
#   net.3.weight                             | norm = 3.010787
#   net.3.bias                               | norm = 0.305876
# Round 0008/50 | Train ACC=84.84%  Val ACC=82.17%  Test ACC=88.24%  Test BACC=88.43%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 9
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 9 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.967593
#   net.0.bias                               | norm = 0.000416
#   net.1.weight                             | norm = 8.504737
#   net.1.bias                               | norm = 0.502917
#   net.3.weight                             | norm = 2.990239
#   net.3.bias                               | norm = 0.309798
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 10
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 10 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.941215
#   net.0.bias                               | norm = 0.000418
#   net.1.weight                             | norm = 8.193034
#   net.1.bias                               | norm = 0.531630
#   net.3.weight                             | norm = 3.002452
#   net.3.bias                               | norm = 0.323050
# Round 0010/50 | Train ACC=83.38%  Val ACC=80.30%  Test ACC=86.82%  Test BACC=86.30%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 11
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 11 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.882740
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 7.881957
#   net.1.bias                               | norm = 0.554367
#   net.3.weight                             | norm = 3.004902
#   net.3.bias                               | norm = 0.328295
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 12
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 12 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.872384
#   net.0.bias                               | norm = 0.000418
#   net.1.weight                             | norm = 7.572229
#   net.1.bias                               | norm = 0.580229
#   net.3.weight                             | norm = 2.998792
#   net.3.bias                               | norm = 0.338411
# Round 0012/50 | Train ACC=82.38%  Val ACC=79.71%  Test ACC=88.71%  Test BACC=88.62%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 13
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 13 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.835844
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 7.263436
#   net.1.bias                               | norm = 0.608313
#   net.3.weight                             | norm = 3.055473
#   net.3.bias                               | norm = 0.350526
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 14
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 14 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.796863
#   net.0.bias                               | norm = 0.000418
#   net.1.weight                             | norm = 6.955533
#   net.1.bias                               | norm = 0.647225
#   net.3.weight                             | norm = 3.075816
#   net.3.bias                               | norm = 0.364374
# Round 0014/50 | Train ACC=82.91%  Val ACC=79.32%  Test ACC=86.35%  Test BACC=85.89%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 15
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 15 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.779311
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 6.648770
#   net.1.bias                               | norm = 0.670003
#   net.3.weight                             | norm = 3.070267
#   net.3.bias                               | norm = 0.372306
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 16
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 16 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.769452
#   net.0.bias                               | norm = 0.000418
#   net.1.weight                             | norm = 6.342296
#   net.1.bias                               | norm = 0.708822
#   net.3.weight                             | norm = 3.129167
#   net.3.bias                               | norm = 0.389023
# Round 0016/50 | Train ACC=81.33%  Val ACC=76.20%  Test ACC=85.88%  Test BACC=85.72%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 17
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 17 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.738542
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 6.038725
#   net.1.bias                               | norm = 0.728074
#   net.3.weight                             | norm = 3.087973
#   net.3.bias                               | norm = 0.393358
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 18
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 18 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.738798
#   net.0.bias                               | norm = 0.000418
#   net.1.weight                             | norm = 5.733912
#   net.1.bias                               | norm = 0.758719
#   net.3.weight                             | norm = 3.044421
#   net.3.bias                               | norm = 0.403174
# Round 0018/50 | Train ACC=80.94%  Val ACC=77.79%  Test ACC=86.59%  Test BACC=86.78%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 19
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 19 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.762268
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 5.435065
#   net.1.bias                               | norm = 0.801042
#   net.3.weight                             | norm = 3.109868
#   net.3.bias                               | norm = 0.422715
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 20
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 20 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.725442
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 5.137887
#   net.1.bias                               | norm = 0.840850
#   net.3.weight                             | norm = 3.101719
#   net.3.bias                               | norm = 0.433946
# Round 0020/50 | Train ACC=80.31%  Val ACC=76.69%  Test ACC=86.12%  Test BACC=86.14%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 21
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 21 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.714437
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 4.844174
#   net.1.bias                               | norm = 0.886395
#   net.3.weight                             | norm = 3.134231
#   net.3.bias                               | norm = 0.449037
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 22
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 22 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.677744
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 4.559566
#   net.1.bias                               | norm = 0.933144
#   net.3.weight                             | norm = 3.143667
#   net.3.bias                               | norm = 0.466493
# Round 0022/50 | Train ACC=79.78%  Val ACC=74.81%  Test ACC=83.76%  Test BACC=83.40%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 23
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 23 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.713238
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 4.288761
#   net.1.bias                               | norm = 0.977612
#   net.3.weight                             | norm = 3.162792
#   net.3.bias                               | norm = 0.480365
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 24
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 24 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.663553
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 4.030144
#   net.1.bias                               | norm = 1.030878
#   net.3.weight                             | norm = 3.199112
#   net.3.bias                               | norm = 0.499614
# Round 0024/50 | Train ACC=80.44%  Val ACC=75.16%  Test ACC=84.94%  Test BACC=84.67%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 25
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 25 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.627197
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.790381
#   net.1.bias                               | norm = 1.074454
#   net.3.weight                             | norm = 3.231487
#   net.3.bias                               | norm = 0.516929
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 26
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 26 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.615167
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.594170
#   net.1.bias                               | norm = 1.113638
#   net.3.weight                             | norm = 3.240103
#   net.3.bias                               | norm = 0.529053
# Round 0026/50 | Train ACC=79.51%  Val ACC=76.27%  Test ACC=84.94%  Test BACC=84.89%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 27
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 27 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.592118
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.432278
#   net.1.bias                               | norm = 1.159382
#   net.3.weight                             | norm = 3.207734
#   net.3.bias                               | norm = 0.544729
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 28
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 28 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.557887
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.298432
#   net.1.bias                               | norm = 1.194370
#   net.3.weight                             | norm = 3.185933
#   net.3.bias                               | norm = 0.556626
# Round 0028/50 | Train ACC=79.24%  Val ACC=73.49%  Test ACC=83.53%  Test BACC=83.42%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 29
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 29 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.551562
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.197271
#   net.1.bias                               | norm = 1.212997
#   net.3.weight                             | norm = 3.185387
#   net.3.bias                               | norm = 0.565948
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 30
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 30 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.525283
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.127153
#   net.1.bias                               | norm = 1.237307
#   net.3.weight                             | norm = 3.194474
#   net.3.bias                               | norm = 0.579532
# Round 0030/50 | Train ACC=77.46%  Val ACC=74.04%  Test ACC=83.06%  Test BACC=82.57%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 31
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 31 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.547978
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.075714
#   net.1.bias                               | norm = 1.255660
#   net.3.weight                             | norm = 3.200422
#   net.3.bias                               | norm = 0.590697
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 32
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 32 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.545379
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.042781
#   net.1.bias                               | norm = 1.267360
#   net.3.weight                             | norm = 3.220999
#   net.3.bias                               | norm = 0.598258
# Round 0032/50 | Train ACC=78.55%  Val ACC=75.68%  Test ACC=83.53%  Test BACC=83.21%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 33
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 33 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.559393
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 3.021963
#   net.1.bias                               | norm = 1.270771
#   net.3.weight                             | norm = 3.206511
#   net.3.bias                               | norm = 0.603472
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 34
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 34 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.523855
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.985897
#   net.1.bias                               | norm = 1.267275
#   net.3.weight                             | norm = 3.167760
#   net.3.bias                               | norm = 0.601014
# Round 0034/50 | Train ACC=77.41%  Val ACC=73.31%  Test ACC=82.82%  Test BACC=82.81%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 35
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 35 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.523711
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.978760
#   net.1.bias                               | norm = 1.278542
#   net.3.weight                             | norm = 3.198415
#   net.3.bias                               | norm = 0.611201
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 36
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 36 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.518794
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.977838
#   net.1.bias                               | norm = 1.293961
#   net.3.weight                             | norm = 3.221021
#   net.3.bias                               | norm = 0.618498
# Round 0036/50 | Train ACC=78.24%  Val ACC=73.91%  Test ACC=82.82%  Test BACC=82.36%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 37
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 37 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.507985
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.978372
#   net.1.bias                               | norm = 1.299210
#   net.3.weight                             | norm = 3.224062
#   net.3.bias                               | norm = 0.620614
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 38
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 38 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.524724
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.958872
#   net.1.bias                               | norm = 1.299204
#   net.3.weight                             | norm = 3.210829
#   net.3.bias                               | norm = 0.628691
# Round 0038/50 | Train ACC=77.17%  Val ACC=74.36%  Test ACC=81.41%  Test BACC=81.40%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 39
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 39 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.521898
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.956486
#   net.1.bias                               | norm = 1.289662
#   net.3.weight                             | norm = 3.230343
#   net.3.bias                               | norm = 0.632989
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 40
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 40 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.512246
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.933878
#   net.1.bias                               | norm = 1.281131
#   net.3.weight                             | norm = 3.181883
#   net.3.bias                               | norm = 0.628958
# Round 0040/50 | Train ACC=76.66%  Val ACC=74.77%  Test ACC=82.12%  Test BACC=82.22%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 41
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 41 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.517721
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.932952
#   net.1.bias                               | norm = 1.285154
#   net.3.weight                             | norm = 3.195077
#   net.3.bias                               | norm = 0.631916
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 42
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 42 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.506021
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.944566
#   net.1.bias                               | norm = 1.288044
#   net.3.weight                             | norm = 3.173665
#   net.3.bias                               | norm = 0.633159
# Round 0042/50 | Train ACC=77.79%  Val ACC=74.85%  Test ACC=83.76%  Test BACC=83.63%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 43
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 43 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.508264
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.950199
#   net.1.bias                               | norm = 1.296050
#   net.3.weight                             | norm = 3.190979
#   net.3.bias                               | norm = 0.633323
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 44
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 44 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.536902
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.928335
#   net.1.bias                               | norm = 1.284387
#   net.3.weight                             | norm = 3.183549
#   net.3.bias                               | norm = 0.629377
# Round 0044/50 | Train ACC=75.20%  Val ACC=71.17%  Test ACC=81.41%  Test BACC=81.17%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 45
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 45 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.518596
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.914701
#   net.1.bias                               | norm = 1.279374
#   net.3.weight                             | norm = 3.194824
#   net.3.bias                               | norm = 0.632962
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 46
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 46 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.509177
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.910581
#   net.1.bias                               | norm = 1.287291
#   net.3.weight                             | norm = 3.202352
#   net.3.bias                               | norm = 0.639890
# Round 0046/50 | Train ACC=77.02%  Val ACC=75.74%  Test ACC=82.82%  Test BACC=83.02%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 47
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 47 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.489923
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.905968
#   net.1.bias                               | norm = 1.280126
#   net.3.weight                             | norm = 3.218755
#   net.3.bias                               | norm = 0.640719
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 48
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 48 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.495194
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.911764
#   net.1.bias                               | norm = 1.287902
#   net.3.weight                             | norm = 3.176310
#   net.3.bias                               | norm = 0.643372
# Round 0048/50 | Train ACC=76.78%  Val ACC=71.48%  Test ACC=82.12%  Test BACC=82.20%
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 49
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 49 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.509505
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.917916
#   net.1.bias                               | norm = 1.290666
#   net.3.weight                             | norm = 3.172472
#   net.3.bias                               | norm = 0.644611
# -----------------------------------------------------------------
# TRAINING FOR ROUND : 50
# TRAINING FOR CLIENT : 0
# TRAINING FOR CLIENT : 2
# TRAINING FOR CLIENT : 3
#
# Round 50 | Global Attention Weight Norms:
#   net.0.weight                             | norm = 1.492381
#   net.0.bias                               | norm = 0.000417
#   net.1.weight                             | norm = 2.921880
#   net.1.bias                               | norm = 1.291938
#   net.3.weight                             | norm = 3.195707
#   net.3.bias                               | norm = 0.642750
# Round 0050/50 | Train ACC=76.67%  Val ACC=72.47%  Test ACC=81.88%  Test BACC=81.80%
# Best client_1 test ACC: 88.71%
# Saved: history.json
# Saved: training_log.json

# %%
import matplotlib.pyplot as plt

rounds = history["rounds"]

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# ── ACC plot ──────────────────────────────────────────────────────────────────
ax = axes[0]
ax.plot(rounds, history["train_acc"], label="Train ACC",  color="steelblue",  linewidth=2)
ax.plot(rounds, history["val_acc"],   label="Val ACC",    color="darkorange",  linewidth=2)
ax.plot(rounds, history["test_acc"],  label="Test ACC (C1)", color="green",   linewidth=2)
ax.set_xlabel("FL Round", fontsize=13)
ax.set_ylabel("Accuracy (%)", fontsize=13)
ax.set_title("Accuracy per FL Round", fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
ax.set_xlim(1, ROUNDS)
ax.set_ylim(0, 100)

# ── BACC plot ─────────────────────────────────────────────────────────────────
ax = axes[1]
ax.plot(rounds, history["train_bacc"], label="Train BACC",     color="steelblue",  linewidth=2)
ax.plot(rounds, history["val_bacc"],   label="Val BACC",       color="darkorange",  linewidth=2)
ax.plot(rounds, history["test_bacc"],  label="Test BACC (C1)", color="green",       linewidth=2)
ax.set_xlabel("FL Round", fontsize=13)
ax.set_ylabel("Balanced Accuracy (%)", fontsize=13)
ax.set_title("Balanced Accuracy per FL Round", fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
ax.set_xlim(1, ROUNDS)
ax.set_ylim(0, 100)

plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/training_curves.png", dpi=150, bbox_inches="tight")
plt.show()
print(f"Plot saved to {OUTPUT_DIR}/training_curves.png")
# Out:
# Plot saved to /content/drive/MyDrive/FACMIC/outputs_target_client_1/training_curves.png

# %%
# Load best checkpoint
global_attention.load_state_dict(
    torch.load(f"{OUTPUT_DIR}/best_attention.pt", map_location=device)
)

print("=" * 55)
print("  Final Results — best checkpoint on client_1 test set")
print("=" * 55)
acc, bacc = evaluate(global_attention, test_loader)
print(f"  Test  ACC  = {acc:.2f}%")
print(f"  Test  BACC = {bacc:.2f}%")

print("\n  Validation on training clients:")
client_list=[0,2,3]
for ind in range(len(val_loaders)):
    cid = client_list[ind]
    vacc, vbacc = evaluate(global_attention, val_loaders[ind])
    print(f"    client_{cid}  ACC={vacc:.2f}%  BACC={vbacc:.2f}%")

# Best round from history
best_round = history["rounds"][
    int(np.argmax(history["test_acc"]))
]
print(f"\n  Best test ACC achieved at round {best_round}")
# Out:
# =======================================================
#   Final Results — best checkpoint on client_1 test set
# =======================================================
#   Test  ACC  = 88.71%
#   Test  BACC = 88.61%
#
#   Validation on training clients:
#     client_0  ACC=86.99%  BACC=86.73%
#     client_2  ACC=86.17%  BACC=86.97%
#     client_3  ACC=76.32%  BACC=75.58%
#
#   Best test ACC achieved at round 4
