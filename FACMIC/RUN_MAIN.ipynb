# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-_jko1kcb
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-_jko1kcb
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.3 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=751e4a63065a269528b53375ce1839dba5c5b6325df33f403c39305788d3fdac
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fhq7ted6/wheels/35/3e/df/3d24cbfb3b6a06f17a2bfd7d1138900d4365d9028aa8f6e92f
# Successfully built clip
# ...

# %%
# %cd /content/drive/MyDrive/FACMIC/
# Out:
# /content/drive/MyDrive/FACMIC

# %%
# !python3 /content/drive/MyDrive/FACMIC/main.py
# Out:
# 100%|███████████████████████████████████████| 335M/335M [00:05<00:00, 66.6MiB/s]
# [0.5217391304347826, 0.14492753623188406, 0.3333333333333333, 0.33333333333]
# ============ Train epoch 0 ============
# 0 0

# %%
# !ls
# Out:
#  adaptation.py		        outputs_1
#  BIOMEDCLIP_FL.ipynb	        Prompt_Generation_using_Ollama.ipynb
# 'Copy of BIOMEDCLIP_FL.ipynb'   __pycache__
#  data			        README.md
#  LICENSE		        results
#  llm_prompts_1.json	        Run_main.ipynb
#  llm_prompts.json	        sheduler.py
#  main.py		        Untitled0.ipynb
#  nets			        utils
#  outputs
